# %% [markdown]
# <a href="https://colab.research.google.com/github/akutayaydin/Magnimind-1/blob/main/Twitter_NLP_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Twitter NLP Classification Project

# %% [markdown]
# Goal: Create a ML model for Business Category tweets

# %%
import pandas as pd

# %%
#For Google Colab
url ='https://raw.githubusercontent.com/akutayaydin/Magnimind-3/main/tweet_data_small.csv'
df = pd.read_csv(url)

# %%
#df = pd.read_csv('tweet_data.csv')

# %%
#Select Business Category Only as Request
df = df[df['topicName'] == 'Business']

# %%
df.head(10)
# Out:
#                tweetID               crDate  edInput  editor  engages  \
# 0  1070867471245164544  2018-12-07 02:27:55       -1      -1       98
# 1  1070868017888837633  2018-12-07 02:30:05       -1      -1       13
# 2  1070868012864028673  2018-12-07 02:30:04       -1      -1       12
# 3  1070867995239555075  2018-12-07 02:30:00       -1      -1        5
# 4  1070867995205885952  2018-12-07 02:30:00       -1      -1        5
# 5  1070868102160769025  2018-12-07 02:30:25       -1      -1       31
# 6  1070868071844376576  2018-12-07 02:30:18       -1      -1        9
# 7  1070868063359262720  2018-12-07 02:30:16       -1      -1        4
# 8  1070868025887387648  2018-12-07 02:30:07       -1      -1       90
# 9  1070875544533663746  2018-12-07 03:00:00       -1      -1        7
#
#    isApproved  isEdNeed   isRT  likes  \
# 0       False      True  False     64
# 1       False      True  False     10
# 2       False      True  False      8
# 3       False      True  False      4
# 4       False      True  False      2
# 5       False      True  False     17
# 6       False      True  False      7
# 7       False      True  False      4
# 8       False      True  False     63
# 9       False      True  False      2
#
#                                           photoUrl  retweets  rtUsID  \
# 0  https://pbs.twimg.com/media/Dtx8SiIWkAImVsb.jpg        34      -1
# 1  https://pbs.twimg.com/media/Dtx8yTyW4AEciqP.jpg         3      -1
# 2                                              NaN         4      -1
# 3                                              NaN         1      -1
# 4                                              NaN         3      -1
# 5  https://pbs.twimg.com/media/Dtx83JvX4AE48aw.jpg        14      -1
# 6                                              NaN         2      -1
# 7                                              NaN         0      -1
# 8                                              NaN        27      -1
# 9                                              NaN         5      -1
#
#                                                 text topicName   usFlwrs  \
# 0  The immediate impulse for an alliance of the E...  Business  23464532
# 1  America's economy is flashing some warning sig...  Business   1732809
# 2  Lyft files for what is expected to be one of t...  Business   2253989
# 3  Exporters still waiting to get Rs 6,000 crore ...  Business   1704056
# 4  Ride-hailing firm Lyft races to leave Uber beh...  Business   1997662
# 5  -Asian stocks post modest gains \n-S&P 500 fut...  Business   5033221
# 6          What's your pick? https://t.co/a0nnFRqIQ3  Business   2318088
# 7  Dick's CEO Ed Stack totals up how many employe...  Business     48736
# 8  A meeting of tech leaders at the White House m...  Business  16198522
# 9  Wall Street recovers slightly from earlier los...  Business   1997685
#
#        usID                   usName  \
# 0   5988062            The Economist
# 1  16184358             CNN Business
# 2  25053299                  FORTUNE
# 3  43855487        Business Standard
# 4  15110357         Reuters Business
# 5  34713362                Bloomberg
# 6   2735591             Fast Company
# 7  14921083        Business Journals
# 8   3108351  The Wall Street Journal
# 9  15110357         Reuters Business
#
#                                             videoUrl
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  https://video.twimg.com/amplify_video/10708116...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  https://video.twimg.com/amplify_video/10708116...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 80000 entries, 0 to 79999
# Data columns (total 18 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   tweetID     80000 non-null  int64
#  1   crDate      80000 non-null  object
#  2   edInput     80000 non-null  int64
#  3   editor      80000 non-null  int64
#  4   engages     80000 non-null  int64
#  5   isApproved  80000 non-null  bool
#  6   isEdNeed    80000 non-null  bool
#  7   isRT        80000 non-null  bool
#  8   likes       80000 non-null  int64
#  9   photoUrl    9615 non-null   object
#  10  retweets    80000 non-null  int64
#  11  rtUsID      80000 non-null  int64
#  12  text        80000 non-null  object
#  13  topicName   80000 non-null  object
#  14  usFlwrs     80000 non-null  int64
#  15  usID        80000 non-null  int64
#  16  usName      80000 non-null  object
#  17  videoUrl    10936 non-null  object
# dtypes: bool(3), int64(9), object(6)
# memory usage: 10.0+ MB

# %% [markdown]
# >Preprocessing starts here

# %%
df_section = df[['tweetID','text','topicName','usID','usName']].copy()

# %% [markdown]
# We dont need these columns.
# 5 unique values for edInput : (5, array([-1,  2,  1,  4,  3]))
# 2 unique values for isApproved: (2, array([False,  True]))
# 12 unique values for editor: (12,
#  array([  -1, 5001, 5003, 5004, 5002, 1001, 2001, 5006, 5101, 5005, 5008,
#         5007]))
# 42 unique values for topicname:(42,
#  array(['Business', 'Animal', 'Memes', 'Nature', 'Travel', 'Interesting',
#         'News', 'Fashion', 'Art', 'Personal Development', 'Motivational',
#         'DIY & Craft', 'Editorial Pics', 'Funny', 'Poem', 'World Leaders',
#         'Entrepreneurship', 'US News', 'Journalists', 'Flowers',
#         'Cryptocurrency', 'Photography', 'Design & Architecture',
#         'Fitness', 'Spirituality', 'Startup', 'Space', 'Technology',
#         'Digital Media & Internet', 'Psychology', 'Science', 'Basketball',
#         'Humor', 'Mindfulness', 'Medical', 'Informative', 'Love', 'Stocks',
#         'Nanotech', 'Biotech', 'science', 'Random'], dtype=object))

# %%
#Remove duplicates from the dataframe

# %%
df_section = df_section.drop_duplicates(subset='text')

# %%
df_section.head()
# Out:
#                tweetID                                               text  \
# 0  1070867471245164544  The immediate impulse for an alliance of the E...
# 1  1070868017888837633  America's economy is flashing some warning sig...
# 2  1070868012864028673  Lyft files for what is expected to be one of t...
# 3  1070867995239555075  Exporters still waiting to get Rs 6,000 crore ...
# 4  1070867995205885952  Ride-hailing firm Lyft races to leave Uber beh...
#
#   topicName      usID             usName
# 0  Business   5988062      The Economist
# 1  Business  16184358       CNN Business
# 2  Business  25053299            FORTUNE
# 3  Business  43855487  Business Standard
# 4  Business  15110357   Reuters Business

# %% [markdown]
# >Tokenize starts here

# %%
import re
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords

# %%
tknz =TweetTokenizer()

# %%
#Extrack link from text
url_pattern = r"([http#]\W+)"

# %%
df_section['tokens'] =''

# %%
df_section.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79957 entries, 0 to 79999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   tweetID    79957 non-null  int64
#  1   text       79957 non-null  object
#  2   topicName  79957 non-null  object
#  3   usID       79957 non-null  int64
#  4   usName     79957 non-null  object
#  5   tokens     79957 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 4.3+ MB

# %%
df_section['tokens'] = df['text'].apply(tknz.tokenize)

# %%
df_section.head()
# Out:
#                tweetID                                               text  \
# 0  1070867471245164544  The immediate impulse for an alliance of the E...
# 1  1070868017888837633  America's economy is flashing some warning sig...
# 2  1070868012864028673  Lyft files for what is expected to be one of t...
# 3  1070867995239555075  Exporters still waiting to get Rs 6,000 crore ...
# 4  1070867995205885952  Ride-hailing firm Lyft races to leave Uber beh...
#
#   topicName      usID             usName  \
# 0  Business   5988062      The Economist
# 1  Business  16184358       CNN Business
# 2  Business  25053299            FORTUNE
# 3  Business  43855487  Business Standard
# 4  Business  15110357   Reuters Business
#
#                                               tokens
# 0  [The, immediate, impulse, for, an, alliance, o...
# 1  [America's, economy, is, flashing, some, warni...
# 2  [Lyft, files, for, what, is, expected, to, be,...
# 3  [Exporters, still, waiting, to, get, Rs, 6,000...
# 4  [Ride-hailing, firm, Lyft, races, to, leave, U...

# %%
df_section.shape
# Out:
# (79957, 6)

# %%
#Convert the list to lowercase
def convert_string_lower(strings):
    newList = []
    for string in strings:
        string = string.replace('\'','') # don't loose words with these character
        string = string.replace('-','') # don't loose words with these character
        newList.append(string.lower())
    return newList

df_section['tokens'] = list(map(convert_string_lower,df_section['tokens']))

# %%
df_section.head(10)
# Out:
#                tweetID                                               text  \
# 0  1070867471245164544  The immediate impulse for an alliance of the E...
# 1  1070868017888837633  America's economy is flashing some warning sig...
# 2  1070868012864028673  Lyft files for what is expected to be one of t...
# 3  1070867995239555075  Exporters still waiting to get Rs 6,000 crore ...
# 4  1070867995205885952  Ride-hailing firm Lyft races to leave Uber beh...
# 5  1070868102160769025  -Asian stocks post modest gains \n-S&P 500 fut...
# 6  1070868071844376576          What's your pick? https://t.co/a0nnFRqIQ3
# 7  1070868063359262720  Dick's CEO Ed Stack totals up how many employe...
# 8  1070868025887387648  A meeting of tech leaders at the White House m...
# 9  1070875544533663746  Wall Street recovers slightly from earlier los...
#
#   topicName      usID                   usName  \
# 0  Business   5988062            The Economist
# 1  Business  16184358             CNN Business
# 2  Business  25053299                  FORTUNE
# 3  Business  43855487        Business Standard
# 4  Business  15110357         Reuters Business
# 5  Business  34713362                Bloomberg
# 6  Business   2735591             Fast Company
# 7  Business  14921083        Business Journals
# 8  Business   3108351  The Wall Street Journal
# 9  Business  15110357         Reuters Business
#
#                                               tokens  \
# 0  [immediate, impulse, alliance, eus, northern, ...
# 1  [americas, economy, flashing, warning, signs, ...
# 2  [lyft, files, expected, one, hottest, ipos, 20...
# 3  [exporters, still, waiting, get, rs, 6,000, cr...
# 4  [ridehailing, firm, lyft, races, leave, uber, ...
# 5  [, asian, stocks, post, modest, gains, , &, p,...
# 6          [whats, pick, ?, https://t.co/a0nnfrqiq3]
# 7  [dicks, ceo, ed, stack, totals, many, employee...
# 8  [meeting, tech, leaders, white, house, marked,...
# 9  [wall, street, recovers, slightly, earlier, lo...
#
#                                           tokens_url  \
# 0  [https://t.co/nlhud36hay, https://t.co/shwmwpj...
# 1  [https://t.co/xvcpgtqmzy, https://t.co/0sqdzas...
# 2                          [https://t.co/qejyniazld]
# 3                          [https://t.co/qrbg8b98rr]
# 4  [https://t.co/0qcsdx2lys, https://t.co/ghzlunt...
# 5  [https://t.co/8cwvkxpowq, https://t.co/ebp6jna...
# 6                          [https://t.co/a0nnfrqiq3]
# 7           [assault-style, https://t.co/kgoa4cq5nr]
# 8                          [https://t.co/blffalegil]
# 9  [https://t.co/vpvab9zrup, https://t.co/0yoxbr7...
#
#                                           tokens_new
# 0  [immediate, impulse, alliance, eus, northern, ...
# 1  [americas, economy, flashing, warning, signs, ...
# 2        [lyft, files, expected, one, hottest, ipos]
# 3  [exporters, still, waiting, get, rs, crore, wo...
# 4  [firm, lyft, races, leave, uber, behind, ipo, ...
# 5  [asian, stocks, post, modest, gains, p, future...
# 6                                      [whats, pick]
# 7  [dicks, ceo, ed, stack, totals, many, employee...
# 8  [meeting, tech, leaders, white, house, marked,...
# 9  [wall, street, recovers, slightly, earlier, lo...

# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#remove stopwords      
nltk_words = stopwords.words('english') 

def remove_stopwords(string):
    output = [w for w in string if w not in nltk_words]
    return output

df_section['tokens'] = df_section['tokens'].apply(remove_stopwords)

# %%
df_section.head(10)
# Out:
#                tweetID                                               text  \
# 0  1070867471245164544  The immediate impulse for an alliance of the E...
# 1  1070868017888837633  America's economy is flashing some warning sig...
# 2  1070868012864028673  Lyft files for what is expected to be one of t...
# 3  1070867995239555075  Exporters still waiting to get Rs 6,000 crore ...
# 4  1070867995205885952  Ride-hailing firm Lyft races to leave Uber beh...
# 5  1070868102160769025  -Asian stocks post modest gains \n-S&P 500 fut...
# 6  1070868071844376576          What's your pick? https://t.co/a0nnFRqIQ3
# 7  1070868063359262720  Dick's CEO Ed Stack totals up how many employe...
# 8  1070868025887387648  A meeting of tech leaders at the White House m...
# 9  1070875544533663746  Wall Street recovers slightly from earlier los...
#
#   topicName      usID                   usName  \
# 0  Business   5988062            The Economist
# 1  Business  16184358             CNN Business
# 2  Business  25053299                  FORTUNE
# 3  Business  43855487        Business Standard
# 4  Business  15110357         Reuters Business
# 5  Business  34713362                Bloomberg
# 6  Business   2735591             Fast Company
# 7  Business  14921083        Business Journals
# 8  Business   3108351  The Wall Street Journal
# 9  Business  15110357         Reuters Business
#
#                                               tokens  \
# 0  [immediate, impulse, alliance, eus, northern, ...
# 1  [americas, economy, flashing, warning, signs, ...
# 2  [lyft, files, expected, one, hottest, ipos, 20...
# 3  [exporters, still, waiting, get, rs, 6,000, cr...
# 4  [ridehailing, firm, lyft, races, leave, uber, ...
# 5  [, asian, stocks, post, modest, gains, , &, p,...
# 6          [whats, pick, ?, https://t.co/a0nnfrqiq3]
# 7  [dicks, ceo, ed, stack, totals, many, employee...
# 8  [meeting, tech, leaders, white, house, marked,...
# 9  [wall, street, recovers, slightly, earlier, lo...
#
#                                           tokens_url  \
# 0  [https://t.co/nlhud36hay, https://t.co/shwmwpj...
# 1  [https://t.co/xvcpgtqmzy, https://t.co/0sqdzas...
# 2                          [https://t.co/qejyniazld]
# 3                          [https://t.co/qrbg8b98rr]
# 4  [https://t.co/0qcsdx2lys, https://t.co/ghzlunt...
# 5  [https://t.co/8cwvkxpowq, https://t.co/ebp6jna...
# 6                          [https://t.co/a0nnfrqiq3]
# 7           [assault-style, https://t.co/kgoa4cq5nr]
# 8                          [https://t.co/blffalegil]
# 9  [https://t.co/vpvab9zrup, https://t.co/0yoxbr7...
#
#                                           tokens_new
# 0  [immediate, impulse, alliance, eus, northern, ...
# 1  [americas, economy, flashing, warning, signs, ...
# 2        [lyft, files, expected, one, hottest, ipos]
# 3  [exporters, still, waiting, get, rs, crore, wo...
# 4  [firm, lyft, races, leave, uber, behind, ipo, ...
# 5  [asian, stocks, post, modest, gains, p, future...
# 6                                      [whats, pick]
# 7  [dicks, ceo, ed, stack, totals, many, employee...
# 8  [meeting, tech, leaders, white, house, marked,...
# 9  [wall, street, recovers, slightly, earlier, lo...

# %%
#Check if any stop words exists
df_section[['the' in x for x in df_section['tokens']]]
# Out:
# Empty DataFrame
# Columns: [tweetID, text, topicName, usID, usName, tokens, tokens_url, tokens_new]
# Index: []

# %%
#find urls and create a new column for them
#TODO: Scrape this url to get more info     
url_pattern = re.compile(r"([http#]\W+)")

def find_url(string):
    output = [w for w in string if url_pattern.search(w)]
    return output

df_section['tokens_url'] = df_section['tokens'].apply(find_url)

# %%
df_section.head(10)
# Out:
#                tweetID                                               text  \
# 0  1070867471245164544  The immediate impulse for an alliance of the E...
# 1  1070868017888837633  America's economy is flashing some warning sig...
# 2  1070868012864028673  Lyft files for what is expected to be one of t...
# 3  1070867995239555075  Exporters still waiting to get Rs 6,000 crore ...
# 4  1070867995205885952  Ride-hailing firm Lyft races to leave Uber beh...
# 5  1070868102160769025  -Asian stocks post modest gains \n-S&P 500 fut...
# 6  1070868071844376576          What's your pick? https://t.co/a0nnFRqIQ3
# 7  1070868063359262720  Dick's CEO Ed Stack totals up how many employe...
# 8  1070868025887387648  A meeting of tech leaders at the White House m...
# 9  1070875544533663746  Wall Street recovers slightly from earlier los...
#
#   topicName      usID                   usName  \
# 0  Business   5988062            The Economist
# 1  Business  16184358             CNN Business
# 2  Business  25053299                  FORTUNE
# 3  Business  43855487        Business Standard
# 4  Business  15110357         Reuters Business
# 5  Business  34713362                Bloomberg
# 6  Business   2735591             Fast Company
# 7  Business  14921083        Business Journals
# 8  Business   3108351  The Wall Street Journal
# 9  Business  15110357         Reuters Business
#
#                                               tokens  \
# 0  [immediate, impulse, alliance, eus, northern, ...
# 1  [americas, economy, flashing, warning, signs, ...
# 2  [lyft, files, expected, one, hottest, ipos, 20...
# 3  [exporters, still, waiting, get, rs, 6,000, cr...
# 4  [ridehailing, firm, lyft, races, leave, uber, ...
# 5  [, asian, stocks, post, modest, gains, , &, p,...
# 6          [whats, pick, ?, https://t.co/a0nnfrqiq3]
# 7  [dicks, ceo, ed, stack, totals, many, employee...
# 8  [meeting, tech, leaders, white, house, marked,...
# 9  [wall, street, recovers, slightly, earlier, lo...
#
#                                           tokens_url  \
# 0  [https://t.co/nlhud36hay, https://t.co/shwmwpj...
# 1  [https://t.co/xvcpgtqmzy, https://t.co/0sqdzas...
# 2                          [https://t.co/qejyniazld]
# 3                          [https://t.co/qrbg8b98rr]
# 4  [https://t.co/0qcsdx2lys, https://t.co/ghzlunt...
# 5  [https://t.co/8cwvkxpowq, https://t.co/ebp6jna...
# 6                          [https://t.co/a0nnfrqiq3]
# 7                          [https://t.co/kgoa4cq5nr]
# 8                          [https://t.co/blffalegil]
# 9  [https://t.co/vpvab9zrup, https://t.co/0yoxbr7...
#
#                                           tokens_new
# 0  [immediate, impulse, alliance, eus, northern, ...
# 1  [americas, economy, flashing, warning, signs, ...
# 2        [lyft, files, expected, one, hottest, ipos]
# 3  [exporters, still, waiting, get, rs, crore, wo...
# 4  [firm, lyft, races, leave, uber, behind, ipo, ...
# 5  [asian, stocks, post, modest, gains, p, future...
# 6                                      [whats, pick]
# 7  [dicks, ceo, ed, stack, totals, many, employee...
# 8  [meeting, tech, leaders, white, house, marked,...
# 9  [wall, street, recovers, slightly, earlier, lo...

# %%
df_section['tokens_new'] = ''

# %%
#remove punctuations

def no_punc(string):
  #for i,tokens in df_section.iterrows():
  #string = string.replace('\'')
  no_punc = [w for w in string if w.isalpha()]
  return no_punc

df_section['tokens_new'] = df_section['tokens'].apply(no_punc)

# %%
df_section.head(50)
# Out:
#                 tweetID                                               text  \
# 0   1070867471245164544  The immediate impulse for an alliance of the E...
# 1   1070868017888837633  America's economy is flashing some warning sig...
# 2   1070868012864028673  Lyft files for what is expected to be one of t...
# 3   1070867995239555075  Exporters still waiting to get Rs 6,000 crore ...
# 4   1070867995205885952  Ride-hailing firm Lyft races to leave Uber beh...
# 5   1070868102160769025  -Asian stocks post modest gains \n-S&P 500 fut...
# 6   1070868071844376576          What's your pick? https://t.co/a0nnFRqIQ3
# 7   1070868063359262720  Dick's CEO Ed Stack totals up how many employe...
# 8   1070868025887387648  A meeting of tech leaders at the White House m...
# 9   1070875544533663746  Wall Street recovers slightly from earlier los...
# 10  1070875308939722752  New research suggests you should set harder go...
# 11  1070874978558640128  Judge orders U.S. State Department to disclose...
# 12  1070874753135607808  #RajasthanElection2018 LIVE: Voting begins, Sa...
# 13  1070874557110804480  A room full of Alpine cheese is one of Bloombe...
# 14  1070874388436680704  #TelanganaElection2018 LIVE: @narendramodi , @...
# 15  1070873296894394369  IBM sells software assets for $1.8 billion to ...
# 16  1070873237507239936  An IPO that could value this biotech firm at a...
# 17  1070873027754086400  He starts every day with a 60-minute routine h...
# 24  Business  3226282347                  INSIDER
# 25  Business      624413              MarketWatch
# 26  Business    34713362                Bloomberg
# 27  Business     5988062            The Economist
# 28  Business     2735591             Fast Company
# 29  Business    43855487        Business Standard
# 30  Business    34713362                Bloomberg
# 31  Business    34713362                Bloomberg
# 32  Business    15110357         Reuters Business
# 33  Business    28175577     WSJ Personal Finance
# 34  Business    20562637         Business Insider
# 35  Business    43855487        Business Standard
# 36  Business    34713362                Bloomberg
# 37  Business    16896485                     Inc.
# 38  Business    15110357         Reuters Business
# 39  Business     1754641             NYT Business
# 40  Business    34713362                Bloomberg
# 41  Business    16896485                     Inc.
# 42  Business      624413              MarketWatch
# 43  Business    15764136          USA TODAY Money
# 44  Business    43855487        Business Standard
# 45  Business    15110357         Reuters Business
# 46  Business    34713362                Bloomberg
# 47  Business    19546277            Yahoo Finance
# 48  Business    34713362                Bloomberg
# 49  Business    15110357         Reuters Business
#
#                                                tokens  \
# 0   [immediate, impulse, alliance, eus, northern, ...
# 1   [americas, economy, flashing, warning, signs, ...
# 2   [lyft, files, expected, one, hottest, ipos, 20...
# 3   [exporters, still, waiting, get, rs, 6,000, cr...
# 4   [ridehailing, firm, lyft, races, leave, uber, ...
# 5   [, asian, stocks, post, modest, gains, , &, p,...
# 6           [whats, pick, ?, https://t.co/a0nnfrqiq3]
# 7   [dicks, ceo, ed, stack, totals, many, employee...
# 8   [meeting, tech, leaders, white, house, marked,...
# 9   [wall, street, recovers, slightly, earlier, lo...
# 10  [new, research, suggests, set, harder, goals, ...
# 11  [judge, orders, u, ., ., state, department, di...
# 12  [#rajasthanelection2018, live, :, voting, begi...
# 13  [room, full, alpine, cheese, one, bloombergs, ...
# 14  [#telanganaelection2018, live, :, @narendramod...
# 15  [ibm, sells, software, assets, $, 1.8, billion...
# 16  [ipo, could, value, biotech, firm, eyepopping,...
# 17  [starts, every, day, 60, , minute, routine, ht...
# 18  [economic, growth, may, become, casualty, tugo...
# 19  [cbs, still, paying, legal, settlement, allega...
# 20  [fiat, chrysler, automobiles, planning, conver...
# 21  [fed, officials, hinting, pace, rate, increase...
# 22  [microsofts, president, says, society, illserv...
# 23  [microsoft, ’, warning, powerful, technology, ...
# 24  [ready, arm, wrestle, ?, 💪, https://t.co/pjelz...
# 25  [", first, time, 10, years, ,, cash, asset, cl...
# 26  [japan, biotech, stock, rockets, 155, %, break...
# 27  [close, inspection, ,, ancient, mythology, tur...
# 28  [collateral, damage, tumblr, ’, porn, ban, htt...
# 29  [market, ahead, :, opening, bell, ,, listen, m...
# 30  [chinese, state, media, call, huawei, cfos, ar...
# 31  [wells, fargo, says, ’, different, bank, today...
# 32  [oil, drops, opec, makes, supply, cut, depende...
# 33  [’, time, start, paying, taxes, like, billiona...
# 34  [kidstance, creates, customized, electric, toy...
# 35  [., @rbi, subcommittee, discuss, easing, lendi...
# 36  [internet, loving, instagrams, latest, glitch,...
# 45                          [https://t.co/seg8gihypt]
# 46                          [https://t.co/golrngzpkw]
# 47  [https://t.co/k9kz9vmqr0, https://t.co/0aoadjr...
# 48                          [https://t.co/xz4ieijho3]
# 49  [https://t.co/kdfutvgp9d, https://t.co/vzubmfj...
#
#                                            tokens_new
# 0   [immediate, impulse, alliance, eus, northern, ...
# 1   [americas, economy, flashing, warning, signs, ...
# 2         [lyft, files, expected, one, hottest, ipos]
# 3   [exporters, still, waiting, get, rs, crore, wo...
# 4   [ridehailing, firm, lyft, races, leave, uber, ...
# 5   [asian, stocks, post, modest, gains, p, future...
# 6                                       [whats, pick]
# 7   [dicks, ceo, ed, stack, totals, many, employee...
# 8   [meeting, tech, leaders, white, house, marked,...
# 9   [wall, street, recovers, slightly, earlier, lo...
# 10      [new, research, suggests, set, harder, goals]
# 11  [judge, orders, u, state, department, disclose...
# 12  [live, voting, begins, satta, market, bets, bi...
# 13  [room, full, alpine, cheese, one, bloombergs, ...
# 14  [live, urge, people, vote, large, numbers, cat...
# 15  [ibm, sells, software, assets, billion, indias...
# 16  [ipo, could, value, biotech, firm, eyepopping,...
# 17              [starts, every, day, minute, routine]
# 18  [economic, growth, may, become, casualty, tugo...
# 19  [cbs, still, paying, legal, settlement, allega...
# 20  [fiat, chrysler, automobiles, planning, conver...
# 21  [fed, officials, hinting, pace, rate, increase...
# 22  [microsofts, president, says, society, illserv...
# 23         [microsoft, warning, powerful, technology]
# 24                              [ready, arm, wrestle]
# 25  [first, time, years, cash, asset, class, compe...
# 26  [japan, biotech, stock, rockets, breakthrough,...
# 27  [close, inspection, ancient, mythology, turns,...
# 28            [collateral, damage, tumblr, porn, ban]
# 29  [market, ahead, opening, bell, listen, markets...
# 30  [chinese, state, media, call, huawei, cfos, ar...
# 31  [wells, fargo, says, different, bank, today, t...
# 32  [oil, drops, opec, makes, supply, cut, depende...
# 33  [time, start, paying, taxes, like, billionaire...
# 34  [kidstance, creates, customized, electric, toy...
# 35  [subcommittee, discuss, easing, lending, curbs...
# 36  [internet, loving, instagrams, latest, glitch,...
# 37  [pantone, color, yearand, surprising, inspirat...
# 38  [ridehailing, firm, lyft, leaves, uber, dust, ...
# 39  [reporters, write, success, minutes, allowed, ...
# 40          [trump, losing, trade, war, one, metrics]
# 41  [year, uc, berkeley, study, reveals, ingredien...
# 42  [walmart, ceo, warns, customers, might, pay, t...
# 43                                      [save, gifts]
# 44  [todays, picks, coal, india, maruti, suzuki, h...
# 45        [asia, shares, struggle, rally, oil, skids]
# 46  [boeing, sticking, upbeat, view, china, even, ...
# 47    [u, factory, orders, post, largest, drop, year]
# 48  [apple, supplier, broadcom, suggests, older, i...
# 49  [nissan, exchairman, ghosn, expected, indicted...

# %%
#use this part to split the text column
#X = df_section.iloc[4:5,5].to_string().split(",")

# %%
Notes:
    1. Check urllinks - related to business websites
    2. Agirlik ortalamasi belirlemek 
    3. drop duplicates
